# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/nfl-big-data-bowl-2025/players.csv
# /kaggle/input/nfl-big-data-bowl-2025/tracking_week_7.csv
# /kaggle/input/nfl-big-data-bowl-2025/tracking_week_9.csv
# /kaggle/input/nfl-big-data-bowl-2025/tracking_week_6.csv
# /kaggle/input/nfl-big-data-bowl-2025/games.csv
# /kaggle/input/nfl-big-data-bowl-2025/tracking_week_8.csv
# /kaggle/input/nfl-big-data-bowl-2025/player_play.csv
# /kaggle/input/nfl-big-data-bowl-2025/tracking_week_4.csv
# /kaggle/input/nfl-big-data-bowl-2025/tracking_week_3.csv
# /kaggle/input/nfl-big-data-bowl-2025/tracking_week_5.csv
# /kaggle/input/nfl-big-data-bowl-2025/tracking_week_1.csv
# /kaggle/input/nfl-big-data-bowl-2025/plays.csv
# /kaggle/input/nfl-big-data-bowl-2025/tracking_week_2.csv

# %%
games = pd.read_csv("/kaggle/input/nfl-big-data-bowl-2025/games.csv")
games
# Out:
#          gameId  season  week   gameDate gameTimeEastern homeTeamAbbr  \
# 0    2022090800    2022     1   9/8/2022        20:20:00           LA
# 1    2022091100    2022     1  9/11/2022        13:00:00          ATL
# 2    2022091101    2022     1  9/11/2022        13:00:00          CAR
# 3    2022091102    2022     1  9/11/2022        13:00:00          CHI
# 4    2022091103    2022     1  9/11/2022        13:00:00          CIN
# ..          ...     ...   ...        ...             ...          ...
# 131  2022110607    2022     9  11/6/2022        13:00:00          WAS
# 132  2022110608    2022     9  11/6/2022        16:05:00          ARI
# 133  2022110609    2022     9  11/6/2022        16:25:00           TB
# 134  2022110610    2022     9  11/6/2022        20:20:00           KC
# 135  2022110700    2022     9  11/7/2022        20:15:00           NO
#
#     visitorTeamAbbr  homeFinalScore  visitorFinalScore
# 0               BUF              10                 31
# 1                NO              26                 27
# 2               CLE              24                 26
# 3                SF              19                 10
# 4               PIT              20                 23
# ..              ...             ...                ...
# 131             MIN              17                 20
# 132             SEA              21                 31
# 133              LA              16                 13
# 134             TEN              20                 17
# 135             BAL              13                 27
#
# [136 rows x 9 columns]

# %%
players = pd.read_csv('/kaggle/input/nfl-big-data-bowl-2025/players.csv')
players[players['displayName'] == 'Amon-Ra St. Brown']
# Out:
#       nflId height  weight birthDate          collegeName position  \
# 1328  53541    6-1     195       NaN  Southern California       WR
#
#             displayName
# 1328  Amon-Ra St. Brown

# %%
player_play = pd.read_csv('/kaggle/input/nfl-big-data-bowl-2025/player_play.csv')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
player_play[(player_play['nflId'] == 53541) & 
            ((player_play['hadRushAttempt'] == 1.0) | (player_play['hadPassReception'] == 1.0)) & 
            (player_play['gameId'] == 2022091802)]
# Out:
#            gameId  playId  nflId teamAbbr  hadRushAttempt  rushingYards  \
# 50940  2022091802      56  53541      DET               0             0
# 51116  2022091802     316  53541      DET               0             0
# 51182  2022091802     390  53541      DET               0             0
# 51468  2022091802     817  53541      DET               0             0
# 51798  2022091802    1303  53541      DET               0             0
# 52038  2022091802    1646  53541      DET               0             0
# 52546  2022091802    2401  53541      DET               0             0
# 52744  2022091802    2710  53541      DET               1            58
# 53162  2022091802    3262  53541      DET               0             0
# 53206  2022091802    3310  53541      DET               0             0
# 53558  2022091802    3800  53541      DET               1            10
#
#        hadDropback  passingYards  sackYardsAsOffense  hadPassReception  \
# 50940            0             0                   0                 1
# 51116            0             0                   0                 1
# 51182            0             0                   0                 1
# 51468            0             0                   0                 1
# 51798            0             0                   0                 1
# 52038            0             0                   0                 1
# 52546            0             0                   0                 1
# 52744            0             0                   0                 0
# 53162            0             0                   0                 1
# 53206            0             0                   0                 1
# 53558            0             0                   0                 0
#
#        receivingYards  wasTargettedReceiver  yardageGainedAfterTheCatch  \
# 50940               3                     1                           6
# 51116              49                     1                          38
# 51182               6                     1                           1
# 51468              13                     1                           0
# 51798              11                     1                           5
# 52038               4                     1                           0
# 52546              11                     1                           2
# 52744               0                     0                           0
# 53162               8                     1                           4
# 53206              11                     1                           0
# 53558               0                     0                           0
#
#        fumbles  fumbleLost  fumbleOutOfBounds  assistedTackle  \
# 50940        0           0                  0               0
# 51116        0           0                  0               0
# 51182        0           0                  0               0
# 51468        0           0                  0               0
# 51798        0           0                  0               0
# 52038        0           0                  0               0
# 52546        0           0                  0               0
# 52744        0           0                  0               0
# 53162        0           0                  0               0
# 53206        0           0                  0               0
# 53558        0           0                  0               0
#
#        forcedFumbleAsDefense  halfSackYardsAsDefense  passDefensed  \
# 50940                      0                       0             0
# 51116                      0                       0             0
# 51182                      0                       0             0
# 51468                      0                       0             0
# 51798                      0                       0             0
# 52038                      0                       0             0
# 52546                      0                       0             0
# 52744                      0                       0             0
# 53162                      0                       0             0
# 53206                      0                       0             0
# 53558                      0                       0             0
#
#        quarterbackHit  sackYardsAsDefense  safetyAsDefense  soloTackle  \
# 50940               0                   0                0           0
# 51116               0                   0                0           0
# 51182               0                   0                0           0
# 51468               0                   0                0           0
# 51798               0                   0                0           0
# 52038               0                   0                0           0
# 52546               0                   0                0           0
# 52744               0                   0                0           0
# 53162               0                   0                0           0
# 53206               0                   0                0           0
# 53558               0                   0                0           0
#
#        tackleAssist  tackleForALoss  tackleForALossYardage  hadInterception  \
# 50940             0               0                      0                0
# 51116             0               0                      0                0
# 51182             0               0                      0                0
# 51468             0               0                      0                0
# 51798             0               0                      0                0
# 52038             0               0                      0                0
# 52546             0               0                      0                0
# 52744             0               0                      0                0
# 53162             0               0                      0                0
# 53206             0               0                      0                0
# 53558             0               0                      0                0
#
#        interceptionYards  fumbleRecoveries  fumbleRecoveryYards  penaltyYards  \
# 50940                  0                 0                    0             0
# 51116                  0                 0                    0             0
# 51182                  0                 0                    0             0
# 51468                  0                 0                    0             0
# 51798                  0                 0                    0             0
# 52038                  0                 0                    0             0
# 52546                  0                 0                    0             0
# 52744                  0                 0                    0             0
# 53162                  0                 0                    0             0
# 53206                  0                 0                    0             0
# 53558                  0                 0                    0             0
#
#       penaltyNames  wasInitialPassRusher  causedPressure  \
# 50940          NaN                   NaN           False
# 51116          NaN                   NaN           False
# 51182          NaN                   NaN           False
# 51468          NaN                   NaN           False
# 51798          NaN                   NaN           False
# 52038          NaN                   NaN           False
# 52546          NaN                   NaN           False
# 52744          NaN                   NaN           False
# 53162          NaN                   NaN           False
# 53206          NaN                   NaN           False
# 53558          NaN                   NaN           False
#
#        timeToPressureAsPassRusher  getOffTimeAsPassRusher inMotionAtBallSnap  \
# 50940                         NaN                     NaN              False
# 51116                         NaN                     NaN              False
# 51182                         NaN                     NaN              False
# 51468                         NaN                     NaN              False
# 51798                         NaN                     NaN              False
# 52038                         NaN                     NaN              False
# 52546                         NaN                     NaN              False
# 52744                         NaN                     NaN               True
# 53162                         NaN                     NaN              False
# 53206                         NaN                     NaN              False
# 53558                         NaN                     NaN               True
#
#       shiftSinceLineset motionSinceLineset  wasRunningRoute routeRan  \
# 50940             False              False              1.0   SCREEN
# 51116              True               True              1.0       IN
# 51182             False              False              1.0    HITCH
# 51468             False              False              1.0       GO
# 51798             False              False              1.0    SLANT
# 52038              True               True              1.0    HITCH
# 52546             False              False              1.0      OUT
# 52744             False               True              NaN      NaN
# 53162             False               True              1.0      OUT
# 53206             False              False              1.0      OUT
# 53558             False               True              NaN      NaN
#
#        blockedPlayerNFLId1  blockedPlayerNFLId2  blockedPlayerNFLId3  \
# 50940                  NaN                  NaN                  NaN
# 51116                  NaN                  NaN                  NaN
# 51182                  NaN                  NaN                  NaN
# 51468                  NaN                  NaN                  NaN
# 51798                  NaN                  NaN                  NaN
# 52038                  NaN                  NaN                  NaN
# 52546                  NaN                  NaN                  NaN
# 52744                  NaN                  NaN                  NaN
# 53162                  NaN                  NaN                  NaN
# 53206                  NaN                  NaN                  NaN
# 53558                  NaN                  NaN                  NaN
#
#        pressureAllowedAsBlocker  timeToPressureAllowedAsBlocker  \
# 50940                       NaN                             NaN
# 51116                       NaN                             NaN
# 51182                       NaN                             NaN
# 51468                       NaN                             NaN
# 51798                       NaN                             NaN
# 52038                       NaN                             NaN
# 52546                       NaN                             NaN
# 52744                       NaN                             NaN
# 53162                       NaN                             NaN
# 53206                       NaN                             NaN
# 53558                       NaN                             NaN
#
#       pff_defensiveCoverageAssignment  \
# 50940                             NaN
# 51116                             NaN
# 51182                             NaN
# 51468                             NaN
# 51798                             NaN
# 52038                             NaN
# 52546                             NaN
# 52744                             NaN
# 53162                             NaN
# 53206                             NaN
# 53558                             NaN
#
#        pff_primaryDefensiveCoverageMatchupNflId  \
# 50940                                       NaN
# 51116                                       NaN
# 51182                                       NaN
# 51468                                       NaN
# 51798                                       NaN
# 52038                                       NaN
# 52546                                       NaN
# 52744                                       NaN
# 53162                                       NaN
# 53206                                       NaN
# 53558                                       NaN
#
#        pff_secondaryDefensiveCoverageMatchupNflId
# 50940                                         NaN
# 51116                                         NaN
# 51182                                         NaN
# 51468                                         NaN
# 51798                                         NaN
# 52038                                         NaN
# 52546                                         NaN
# 52744                                         NaN
# 53162                                         NaN
# 53206                                         NaN
# 53558                                         NaN

# %%
plays = pd.read_csv('/kaggle/input/nfl-big-data-bowl-2025/plays.csv')
plays
# Out:
#            gameId  playId  \
# 0      2022102302    2655
# 1      2022091809    3698
# 2      2022103004    3146
# 3      2022110610     348
# 4      2022102700    2799
# ...           ...     ...
# 16119  2022110604    1051
# 16120  2022103005    3492
# 16121  2022092502    2337
# 16122  2022091809     719
# 16123  2022101602    3046
#
#                                                                                      playDescription  \
# 0           (1:54) (Shotgun) J.Burrow pass short middle to T.Boyd to CIN 30 for 9 yards (J.Hawkins).
# 1       (2:13) (Shotgun) J.Burrow pass short right to H.Hurst to CIN 12 for 4 yards (L.Vander Esch).
# 2            (2:00) (Shotgun) D.Mills pass short right to D.Pierce to HST 26 for 6 yards (D.Walker).
# 3      (9:28) (Shotgun) P.Mahomes pass short left to I.Pacheco to TEN 19 for 4 yards (Z.Cunningham).
# 4                   (2:16) (Shotgun) L.Jackson up the middle to TB 28 for -1 yards (R.Nunez-Roches).
# ...                                                                                              ...
# 16119                          (12:49) (Shotgun) T.Lawrence pass incomplete short right to E.Engram.
# 16120                                        (12:32) (Shotgun) K.Cousins pass incomplete deep right.
# 16121               (9:59) (Shotgun) P.Mahomes scrambles right end to IND 3 for 10 yards (R.Thomas).
# 16122                                             (:45) C.Rush pass incomplete deep right to C.Lamb.
# 16123                                         (15:00) Br.Hall up the middle for 34 yards, TOUCHDOWN.
#
#        quarter  down  yardsToGo possessionTeam defensiveTeam yardlineSide  \
# 0            3     1         10            CIN           ATL          CIN
# 1            4     1         10            CIN           DAL          CIN
# 2            4     3         12            HOU           TEN          HOU
# 3            1     2         10             KC           TEN          TEN
# 4            3     2          8            BAL            TB           TB
# ...        ...   ...        ...            ...           ...          ...
# 16119        2     3          4            JAX            LV          JAX
# 16120        4     1         10            MIN           ARI          MIN
# 16121        3     1         10             KC           IND          IND
# 16122        1     1         10            DAL           CIN          CIN
# 16123        4     1         10            NYJ            GB           GB
#
#        yardlineNumber gameClock  preSnapHomeScore  preSnapVisitorScore  \
# 0                  21     01:54                35                   17
# 1                   8     02:13                17                   17
# 2                  20     02:00                 3                   17
# 3                  23     09:28                 0                    0
# 4                  27     02:16                10                   10
# ...               ...       ...               ...                  ...
# 16119              31     12:49                 0                   10
# 16120              25     12:32                28                   26
# 16121              13     09:59                10                   14
# 16122              47     00:45                 7                    3
# 16123              34     15:00                10                   17
#
#       playNullifiedByPenalty  absoluteYardlineNumber  \
# 0                          N                      31
# 1                          N                      18
# 2                          N                      30
# 3                          N                      33
# 4                          N                      37
# ...                      ...                     ...
# 16119                      N                      79
# 16120                      N                      35
# 16121                      N                      97
# 16122                      N                      57
# 16123                      N                      44
#
#        preSnapHomeTeamWinProbability  preSnapVisitorTeamWinProbability  \
# 0                           0.982017                          0.017983
# 1                           0.424356                          0.575644
# 2                           0.006291                          0.993709
# 3                           0.884223                          0.115777
# 4                           0.410371                          0.589629
# ...                              ...                               ...
# 16119                       0.207444                          0.792556
# 16120                       0.724565                          0.275435
# 16121                       0.165774                          0.834226
# 16122                       0.519735                          0.480265
# 16123                       0.139006                          0.860994
#
#        expectedPoints offenseFormation receiverAlignment  playClockAtSnap  \
# 0            0.719313            EMPTY               3x2             10.0
# 1            0.607746            EMPTY               3x2              9.0
# 2           -0.291485          SHOTGUN               2x2             12.0
# 3            4.249382          SHOTGUN               2x2             11.0
# 4            3.928413           PISTOL               3x1              8.0
# ...               ...              ...               ...              ...
# 16119        0.702276          SHOTGUN               2x2              9.0
# 16120        1.600202          SHOTGUN               2x2             12.0
# 16121        5.127508          SHOTGUN               2x2              6.0
# 16122        2.926312       SINGLEBACK               2x2              3.0
# 16123        3.844564       SINGLEBACK               3x1             13.0
#
#       passResult  passLength  targetX  targetY  playAction  dropbackType  \
# 0              C         6.0    36.69    16.51       False   TRADITIONAL
# 1              C         4.0    20.83    20.49       False   TRADITIONAL
# 2              C        -4.0    26.02    17.56       False   TRADITIONAL
# 3              C        -6.0    38.95    14.19       False   TRADITIONAL
# 4            NaN         NaN      NaN      NaN        True  DESIGNED_RUN
# ...          ...         ...      ...      ...         ...           ...
# 16119          I         6.0    72.69    39.92       False   TRADITIONAL
# 16120          I        20.0      NaN      NaN       False   TRADITIONAL
# 16121          R         NaN      NaN      NaN       False      SCRAMBLE
# 16122          I        38.0    21.89    49.48        True   TRADITIONAL
# 16123        NaN         NaN      NaN      NaN       False           NaN
#
#        dropbackDistance passLocationType  timeToThrow  timeInTackleBox  \
# 0                  2.40       INSIDE_BOX        2.990            2.990
# 1                  1.14       INSIDE_BOX        1.836            1.836
# 2                  3.20       INSIDE_BOX        2.236            2.236
# 3                  3.02       INSIDE_BOX        2.202            2.202
# 4                  2.03              NaN          NaN              NaN
# ...                 ...              ...          ...              ...
# 16119              1.67       INSIDE_BOX        1.860            1.860
# 16120              2.24       INSIDE_BOX        3.136            3.136
# 16121              3.28              NaN          NaN              NaN
# 16122              6.64       INSIDE_BOX        3.070            3.070
# 16123               NaN              NaN          NaN              NaN
#
#        timeToSack passTippedAtLine unblockedPressure qbSpike  qbKneel qbSneak  \
# 0             NaN            False             False   False        0     NaN
# 1             NaN            False             False   False        0     NaN
# 2             NaN            False             False   False        0     NaN
# 3             NaN            False             False   False        0     NaN
# 4             NaN              NaN               NaN     NaN        0   False
# ...           ...              ...               ...     ...      ...     ...
# 16119         NaN            False             False   False        0     NaN
# 16120         NaN            False             False   False        0     NaN
# 16121         NaN              NaN             False     NaN        0   False
# 16122         NaN            False             False   False        0     NaN
# 16123         NaN              NaN               NaN     NaN        0   False
#
#       rushLocationType  penaltyYards  prePenaltyYardsGained  yardsGained  \
# 0                  NaN           NaN                      9            9
# 1                  NaN           NaN                      4            4
# 2                  NaN           NaN                      6            6
# 3                  NaN           NaN                      4            4
# 4          INSIDE_LEFT           NaN                     -1           -1
# ...                ...           ...                    ...          ...
# 16119              NaN           NaN                      0            0
# 16120              NaN           NaN                      0            0
# 16121     INSIDE_RIGHT           NaN                     10           10
# 16122              NaN           NaN                      0            0
# 16123      INSIDE_LEFT           NaN                     34           34
#
#        homeTeamWinProbabilityAdded  visitorTeamWinProbilityAdded  \
# 0                         0.004634                     -0.004634
# 1                         0.002847                     -0.002847
# 2                         0.000205                     -0.000205
# 3                        -0.001308                      0.001308
# 4                         0.027141                     -0.027141
# ...                            ...                           ...
# 16119                    -0.024741                      0.024741
# 16120                    -0.026580                      0.026580
# 16121                    -0.013790                      0.013790
# 16122                    -0.011561                      0.011561
# 16123                    -0.051177                      0.051177
#
#        expectedPointsAdded  isDropback pff_runConceptPrimary  \
# 0                 0.702717        True                   NaN
# 1                -0.240509        True                   NaN
# 2                -0.218480        True                   NaN
# 3                -0.427749        True                   NaN
# 4                -0.638912       False                   MAN
# ...                    ...         ...                   ...
# 16119            -1.391687        True                   NaN
# 16120            -0.503208        True                   NaN
# 16121             1.073898        True                   NaN
# 16122            -0.522397        True             UNDEFINED
# 16123             3.155436       False               COUNTER
#
#       pff_runConceptSecondary  pff_runPassOption pff_passCoverage pff_manZone
# 0                         NaN                  0          Cover-3        Zone
# 1                         NaN                  0         Quarters        Zone
# 2                         NaN                  0         Quarters        Zone
# 3                         NaN                  0         Quarters        Zone
# 4                 READ OPTION                  0          Cover-1         Man
# ...                       ...                ...              ...         ...
# 16119                     NaN                  0          Cover-2        Zone
# 16120                     NaN                  0          Cover-3        Zone
# 16121                     NaN                  0         Quarters        Zone
# 16122                     NaN                  0          Cover-3        Zone
# 16123            MISDIRECTION                  0          Cover-3        Zone
#
# [16124 rows x 50 columns]

# %%
plays[(plays['playId'] == 2710) & (plays['gameId'] == 2022091802)]
# Out:
#           gameId  playId  \
# 6533  2022091802    2710
#
#                                                                   playDescription  \
# 6533  (2:58) A.St. Brown right end pushed ob at WAS 17 for 58 yards (B.St-Juste).
#
#       quarter  down  yardsToGo possessionTeam defensiveTeam yardlineSide  \
# 6533        3     1         10            DET           WAS          DET
#
#       yardlineNumber gameClock  preSnapHomeScore  preSnapVisitorScore  \
# 6533              25     02:58                22                   15
#
#      playNullifiedByPenalty  absoluteYardlineNumber  \
# 6533                      N                      35
#
#       preSnapHomeTeamWinProbability  preSnapVisitorTeamWinProbability  \
# 6533                       0.797227                          0.202773
#
#       expectedPoints offenseFormation receiverAlignment  playClockAtSnap  \
# 6533        1.226062       SINGLEBACK               3x1             12.0
#
#      passResult  passLength  targetX  targetY  playAction dropbackType  \
# 6533        NaN         NaN      NaN      NaN       False          NaN
#
#       dropbackDistance passLocationType  timeToThrow  timeInTackleBox  \
# 6533               NaN              NaN          NaN              NaN
#
#       timeToSack passTippedAtLine unblockedPressure qbSpike  qbKneel qbSneak  \
# 6533         NaN              NaN               NaN     NaN        0   False
#
#      rushLocationType  penaltyYards  prePenaltyYardsGained  yardsGained  \
# 6533    OUTSIDE_RIGHT           NaN                     58           58
#
#       homeTeamWinProbabilityAdded  visitorTeamWinProbilityAdded  \
# 6533                     0.070197                     -0.070197
#
#       expectedPointsAdded  isDropback pff_runConceptPrimary  \
# 6533             3.804456       False                 TRICK
#
#      pff_runConceptSecondary  pff_runPassOption pff_passCoverage pff_manZone
# 6533                     NaN                  0          Cover-3        Zone

# %%
tracking_week_2 = pd.read_csv("/kaggle/input/nfl-big-data-bowl-2025/tracking_week_2.csv")

# %%
full_play = tracking_week_2[(tracking_week_2["gameId"] == 2022091802) & (tracking_week_2["playId"] == 316)]
full_play
# Out:
#              gameId  playId    nflId   displayName  frameId    frameType  \
# 4962963  2022091802     316  42488.0  Bobby McCain        1  BEFORE_SNAP
# 4962964  2022091802     316  42488.0  Bobby McCain        2  BEFORE_SNAP
# 4962965  2022091802     316  42488.0  Bobby McCain        3  BEFORE_SNAP
# 4962966  2022091802     316  42488.0  Bobby McCain        4  BEFORE_SNAP
# 4962967  2022091802     316  42488.0  Bobby McCain        5  BEFORE_SNAP
# ...             ...     ...      ...           ...      ...          ...
# 4969053  2022091802     316      NaN      football      261   AFTER_SNAP
# 4969054  2022091802     316      NaN      football      262   AFTER_SNAP
# 4969055  2022091802     316      NaN      football      263   AFTER_SNAP
# 4969056  2022091802     316      NaN      football      264   AFTER_SNAP
# 4969057  2022091802     316      NaN      football      265   AFTER_SNAP
#
#                           time  jerseyNumber      club playDirection  \
# 4962963  2022-09-18 17:12:34.6          20.0       WAS         right
# 4962964  2022-09-18 17:12:34.7          20.0       WAS         right
# 4962965  2022-09-18 17:12:34.8          20.0       WAS         right
# 4962966  2022-09-18 17:12:34.9          20.0       WAS         right
# 4962967    2022-09-18 17:12:35          20.0       WAS         right
# ...                        ...           ...       ...           ...
# 4969053  2022-09-18 17:13:00.6           NaN  football         right
# 4969054  2022-09-18 17:13:00.7           NaN  football         right
# 4969055  2022-09-18 17:13:00.8           NaN  football         right
# 4969056  2022-09-18 17:13:00.9           NaN  football         right
# 4969057    2022-09-18 17:13:01           NaN  football         right
#
#                  x          y     s     a   dis       o     dir          event
# 4962963  43.450000  27.430000  2.59  0.45  0.26  279.21  138.80            NaN
# 4962964  43.630000  27.230000  2.61  0.38  0.26  285.62  137.71            NaN
# 4962965  43.810000  27.040000  2.65  0.38  0.26  290.72  136.80            NaN
# 4962966  43.990000  26.850000  2.67  0.49  0.27  298.06  135.41            NaN
# 4962967  44.180000  26.660000  2.67  0.45  0.27  303.54  134.71            NaN
# ...            ...        ...   ...   ...   ...     ...     ...            ...
# 4969053  87.300003  54.619999  9.09  2.09  0.92     NaN     NaN  out_of_bounds
# 4969054  88.139999  54.959999  9.00  2.07  0.91     NaN     NaN            NaN
# 4969055  88.970001  55.310001  8.85  2.16  0.90     NaN     NaN            NaN
# 4969056  89.779999  55.650002  8.68  2.23  0.88     NaN     NaN            NaN
# 4969057  90.589996  56.000000  8.60  2.09  0.88     NaN     NaN            NaN
#
# [6095 rows x 18 columns]

# %%
amon_ra_play = tracking_week_2[(tracking_week_2["playId"] == 56) & (tracking_week_2["nflId"] == 53541)]
amon_ra_play
# Out:
#              gameId  playId    nflId        displayName  frameId    frameType  \
# 4938310  2022091802      56  53541.0  Amon-Ra St. Brown        1  BEFORE_SNAP
# 4938311  2022091802      56  53541.0  Amon-Ra St. Brown        2  BEFORE_SNAP
# 4938312  2022091802      56  53541.0  Amon-Ra St. Brown        3  BEFORE_SNAP
# 4938313  2022091802      56  53541.0  Amon-Ra St. Brown        4  BEFORE_SNAP
# 4938314  2022091802      56  53541.0  Amon-Ra St. Brown        5  BEFORE_SNAP
# ...             ...     ...      ...                ...      ...          ...
# 4938396  2022091802      56  53541.0  Amon-Ra St. Brown       87   AFTER_SNAP
# 4938397  2022091802      56  53541.0  Amon-Ra St. Brown       88   AFTER_SNAP
# 4938398  2022091802      56  53541.0  Amon-Ra St. Brown       89   AFTER_SNAP
# 4938399  2022091802      56  53541.0  Amon-Ra St. Brown       90   AFTER_SNAP
# 4938400  2022091802      56  53541.0  Amon-Ra St. Brown       91   AFTER_SNAP
#
#                           time  jerseyNumber club playDirection      x      y  \
# 4938310  2022-09-18 17:03:18.3          14.0  DET         right  28.01  21.37
# 4938311  2022-09-18 17:03:18.4          14.0  DET         right  28.09  21.01
# 4938312  2022-09-18 17:03:18.5          14.0  DET         right  28.18  20.63
# 4938313  2022-09-18 17:03:18.6          14.0  DET         right  28.26  20.23
# 4938314  2022-09-18 17:03:18.7          14.0  DET         right  28.34  19.82
# ...                        ...           ...  ...           ...    ...    ...
# 4938396  2022-09-18 17:03:26.9          14.0  DET         right  38.88  -0.89
# 4938397    2022-09-18 17:03:27          14.0  DET         right  39.15  -1.28
# 4938398  2022-09-18 17:03:27.1          14.0  DET         right  39.41  -1.64
# 4938399  2022-09-18 17:03:27.2          14.0  DET         right  39.67  -1.98
# 4938400  2022-09-18 17:03:27.3          14.0  DET         right  39.92  -2.29
#
#             s     a   dis       o     dir                 event
# 4938310  3.54  2.18  0.34  138.74  165.65  huddle_break_offense
# 4938311  3.81  1.86  0.37  144.54  167.19                   NaN
# 4938312  4.00  1.48  0.39  149.83  167.77                   NaN
# 4938313  4.12  0.98  0.41  152.27  168.15                   NaN
# 4938314  4.23  0.73  0.42  153.00  169.15                   NaN
# ...       ...   ...   ...     ...     ...                   ...
# 4938396  4.90  1.60  1.09  116.58  146.00         out_of_bounds
# 4938397  4.68  1.96  0.47  115.28  144.47                   NaN
# 4938398  4.43  2.23  0.45  117.45  143.39                   NaN
# 4938399  4.16  2.43  0.43  115.77  142.07                   NaN
# 4938400  3.84  2.70  0.39  111.47  141.15                   NaN
#
# [91 rows x 18 columns]

# %%
import plotly.express as px
fig = px.scatter(
    full_play, x='x', y='y', animation_frame='frameId', animation_group='displayName', color='club',
    range_x=[0,100], range_y=[0,50]
)

fig
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="3f59d58b-85ff-407f-bea8-3226355cf68c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3f59d58b-85ff-407f-bea8-3226355cf68c")) {                    Plotly.newPlot(                        "3f59d58b-85ff-407f-bea8-3226355cf68c",                        [{"hovertemplate":"club=WAS\u003cbr\u003eframeId=1\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["Bobby McCain","William Jackson","Kendall Fuller","Jonathan Allen","Daron Payne","Montez Sweat","Cole Holcomb","James Smith-Williams","Jamin Davis","Benjamin St-Juste","Darrick Forrest"],"legendgroup":"WAS","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"WAS","orientation":"v","showlegend":true,"x":[43.45,41.49,41.52,39.08,38.83,38.71,40.69,39.66,41.01,42.84,43.75],"xaxis":"x","y":[27.43,25.74,35.76,31.18,28.28,33.25,29.8,26.93,31.27,28.52,32.43],"yaxis":"y","type":"scatter"},{"hovertemplate":"club=DET\u003cbr\u003eframeId=1\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["Jared Goff","Taylor Decker","Josh Reynolds","Dan Skipper","D.J. Chark","Evan Brown","T.J. Hockenson","D'Andre Swift","Logan Stenberg","Penei Sewell","Amon-Ra St. Brown"],"legendgroup":"DET","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"DET","orientation":"v","showlegend":true,"x":[32.01,34.43,31.82,35.1,30.75,35.63,32.22,30.74,35.05,34.76,33.57],"xaxis":"x","y":[29.86,32.73,32.59,31.52,37.65,29.88,20.43,31.33,28.38,26.96,23.52],"yaxis":"y","type":"scatter"},{"hovertemplate":"club=football\u003cbr\u003eframeId=1\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["football"],"legendgroup":"football","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"football","orientation":"v","showlegend":true,"x":[36.8300018310547],"xaxis":"x","y":[30.0699996948242],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0. ...

# %%
wsh_game = player_play[(player_play['nflId'] == 53541) & 
            ((player_play['hadRushAttempt'] == 1.0) | (player_play['hadPassReception'] == 1.0)) & 
            (player_play['gameId'] == 2022091802)]['playId'].to_numpy()
wsh_game = wsh_game.tolist()
wsh_game
# Out:
# [56, 316, 390, 817, 1303, 1646, 2401, 2710, 3262, 3310, 3800]

# %%
amon_ra_plays = tracking_week_2[tracking_week_2['playId'].isin(wsh_game)]
amon_ra_plays
# Out:
#              gameId  playId    nflId    displayName  frameId    frameType  \
# 765440   2022091812      56  29851.0  Aaron Rodgers        1  BEFORE_SNAP
# 765441   2022091812      56  29851.0  Aaron Rodgers        2  BEFORE_SNAP
# 765442   2022091812      56  29851.0  Aaron Rodgers        3  BEFORE_SNAP
# 765443   2022091812      56  29851.0  Aaron Rodgers        4  BEFORE_SNAP
# 765444   2022091812      56  29851.0  Aaron Rodgers        5  BEFORE_SNAP
# ...             ...     ...      ...            ...      ...          ...
# 5385284  2022091802    3800      NaN       football      145   AFTER_SNAP
# 5385285  2022091802    3800      NaN       football      146   AFTER_SNAP
# 5385286  2022091802    3800      NaN       football      147   AFTER_SNAP
# 5385287  2022091802    3800      NaN       football      148   AFTER_SNAP
# 5385288  2022091802    3800      NaN       football      149   AFTER_SNAP
#
#                           time  jerseyNumber      club playDirection  \
# 765440   2022-09-19 00:23:09.1          12.0        GB          left
# 765441   2022-09-19 00:23:09.2          12.0        GB          left
# 765442   2022-09-19 00:23:09.3          12.0        GB          left
# 765443   2022-09-19 00:23:09.4          12.0        GB          left
# 765444   2022-09-19 00:23:09.5          12.0        GB          left
# ...                        ...           ...       ...           ...
# 5385284  2022-09-18 20:00:31.6           NaN  football          left
# 5385285  2022-09-18 20:00:31.7           NaN  football          left
# 5385286  2022-09-18 20:00:31.8           NaN  football          left
# 5385287  2022-09-18 20:00:31.9           NaN  football          left
# 5385288    2022-09-18 20:00:32           NaN  football          left
#
#                  x      y     s     a   dis       o    dir  \
# 765440   90.270000  29.77  0.13  0.12  0.01  277.00  78.33
# 765441   90.280000  29.80  0.13  0.12  0.03  276.40  62.67
# 765442   90.280000  29.80  0.11  0.11  0.01  276.40  59.33
# 765443   90.290000  29.82  0.10  0.10  0.01  276.40  54.20
# 765444   90.290000  29.82  0.09  0.09  0.01  276.99  50.84
# ...            ...    ...   ...   ...   ...     ...    ...
# 5385284  42.349998  13.75  2.56  4.35  0.21     NaN    NaN
# 5385285  42.189999  13.86  1.90  4.60  0.19     NaN    NaN
# 5385286  42.049999  13.98  1.54  4.35  0.18     NaN    NaN
# 5385287  41.959999  14.07  1.16  3.98  0.14     NaN    NaN
# 5385288  41.900002  14.17  0.78  3.68  0.11     NaN    NaN
#
#                         event
# 765440   huddle_break_offense
# 765441                    NaN
# 765442                    NaN
# 765443                    NaN
# 765444                    NaN
# ...                       ...
# 5385284                tackle
# 5385285                   NaN
# 5385286                   NaN
# 5385287                   NaN
# 5385288                   NaN
#
# [72220 rows x 18 columns]

# %%
fig = px.scatter(
    amon_ra_plays, x='x', y='y', animation_frame='frameId', animation_group='playId', 
    range_x=[0,100], range_y=[0,50]
)

fig
# Out:
# <div>                            <div id="37258846-cde8-452e-868d-5e0da9d2f2a8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("37258846-cde8-452e-868d-5e0da9d2f2a8")) {                    Plotly.newPlot(                        "37258846-cde8-452e-868d-5e0da9d2f2a8",                        [{"hovertemplate":"frameId=1\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","ids":[56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,1303,1303,1303,1303,1303,1303,1303,1303,1303,1303,1303,1303,1303,1303,1303,1303,1303,1303,1303,1303,1303,1303,1303,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56,316,316,316,316,316,316,316,316,316,316,316,316,316,316,316,316,316,316,316,316,316,316,316,390,390,390,390,390,390,390,390,390,390,390,390,390,390,390,390,390,390,390,390,390,390,390,817,817,817,817,817,817,817,817,817,817,817,817,817,817,817,817,817,817,817,817,817,817,817,1303,1303,1303,1303,1303,1303,1303,1303,1303,1303,1303,1303,1303,1303,1303,1303,1303,1303,1303,1303,1303,1303,1303,1646,1646,1646,1646,1646,1646,1646,1646,1646,1646,1646,1646,1646,1646,1646,1646,1646,1646,1646,1646,1646,1646,1646,2401,2401,2401,2401,2401,2401,2401,2401,2401,2401,2401,2401,2401,2401,2401,2401,2401,2401,2401,2401,2401,2401,2401,2710,2710,2710,2710,2710,2710,2710,2710,2710,2710,2710,2710,2710,2710,2710,2710,2710,2710,2710,2710,2710,2710,2710,3262,3262,3262,3262,3262,3262,3262,3262,3262,3262,3262,3262,3262,3262,3262,3262,3262,3262,3262,3262,3262,3262,3262,3310,3310,3310,3310,3310,3310,3310,3310,3310,3310,3310,3310,3310,3310,3310,3310,3310,3310,3310,3310,3310,3310,3310,3800,3800,3800,3800,3800,3800,3800,3800,3800,3800,3800,3800,3800,3800,3800,3800,3800,3800,3800,3800,3800,3800,3800],"legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[90.27,85.96,84.49,86.6,86.06,84.12,75.08,90.45,84.07,80.93,80.73,84.3,86.66,86.14,86.72,82.79,83.1,86.39,85.66,86.31,83.18,74.98,85.2699966430664,36.05,29.08,26.3,38.02,28.44,39.8,29.57,38.61,29.2,38.48,27.38,27.42,35.54,36.84,27.38,30.58,41.0,30.03,35.93,37.6,36.62,30.13,34.75,80.19,91.48,82.27,84.02,88.32,84.27,81.86,89.45,90.45,84.08,90.39,84.13,86.93,89.69,84.36,81.76,83.32,89.81,91.18,80.39,88.46,92.41,85.2699966430664,90.44,92.07,82.89,81.63,82.92,83.06,84.21,92.96,83.92,91.93,80.57,83.51,83.81,91.22,80.8,92.05,82.88,90.17,90.72,90.25,91.09,91.36,85.0400009155273,82.22,91.97,90.11,82.01,91.32,81.02,81.12,82.65,83.44,90.85,89.59,89.99,90.55,79.69,82.69,83.99,79.55,93.11,91.62,80.53,89.43,91.85,85.1999969482422,73.48,81.79,81.44,79.99,78.78,69.96,74.54,73.09,69.73,81.01,81.64,70.61,79.68,69.77,72.13,71.13,81.36,73.17,73.85,79.15,80.49,79.49,76.0699996948242,91.59,81.61,83.38,84.03,89.76,83.32,90.9,89.47,90.6,90.06,83.86,82.25,81.99,89.64,83.83,79.92,89.71,79.19,90.57,84.08,91.72,90.47,85.0599975585938,44.59,28.8,30.55,40.98,39.65,37.42,26.84,30.06,36.07,27.62,30.28,28.82,36.54,40.04,36.53,27.94,29.74,37.07,29.25,42.04,28.01,43.09,34.810001373291,43.45,32.01,34.43,41.49,41.52,39.08,31.82,35.1,38.83,30.75,35.63,32.22,38.71,40.69,30.74,35.05,39.66,34.76,41.01,42.84,33.57,43.75,36.8300018310547,97.54,82.12,85.32,92.97,92.56,89.17,81.7,85.34,89.62,82.13,86.03,84.35,89.44,92.34,82.26,85.4,89.18,84.15,92.17,93.54,83.39,96.49,87.2600021362305,99.91,102.45,91.17,92.83,101.55,100.44,99.44,89.85,93.13,99.57,89.77,92.81,92 ...

# %%
import plotly.graph_objects as go

fig_dict = {
    'data': [],
    'layout': {},
    'frames': []
}

fig_dict['layout']['xaxis'] = {'range': [0, 100], 'title': 'x'}
fig_dict['layout']['yaxis'] = {'range': [0, 50], 'title': 'y'}
fig_dict['layout']['hovermode'] = 'displayName'
fig_dict['layout']['updatemenus'] = [
    {
        "buttons": [
            {
                'args': [None, {'frame': {'duration': 500, 'redraw':False},
                                'fromcurrent': True, 'transition': {'duration': 1000}}],
                'label': 'Play',
                'method': 'animate'
            },
            {
                'args': [[None], {'frame': {'duration': 0, 'redraw': False},
                                  'mode': 'immediate',
                                  'transition': {'duration': 0}}],
                'label': 'Pause',
                'method': 'animate'
            }
        ],
        'direction': 'left',
        'pad': {'r': 10, 't': 87},
        'showactive': False,
        'type': 'buttons',
        'x': 0.1,
        'xanchor': 'right',
        'y': 0,
        'yanchor': 'top'
    }
]

sliders_dict = {
    'active': 0,
    'yanchor': 'top',
    'xanchor': 'left',
    'currentvalue': {
        'font': {'size': 20},
        'prefix': 'Time:',
        'visible': True,
        'xanchor': 'right'
    },
    'transition': {'duration': 300},
    'pad': {'b': 10, 't': 50},
    'len': .9,
    'x': .1,
    'y': 0,
    'steps': []
}

frames = []
for frame in full_play['frameId']:
    data = []
    data.append(
        go.Scatter(
            x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 63
#      59 for frame in full_play['frameId']:
#      60     data = []
#      61     data.append(
#      62         go.Scatter(
# ---> 63             x))
#
# NameError: name 'x' is not defined

# %%
import plotly.graph_objects as go


fig_dict = {
    'data': [],
    'layout': {},
    'frames': []
}

fig_dict['layout']['xaxis'] = {
    'range': [0, 100],
    'title': {'text': 'x', 'font': {'color': 'white'}},  
    'linecolor': 'black',  
    'tickcolor': 'black',  
    'dtick': 10, 
    'showgrid': True 
}

fig_dict['layout']['yaxis'] = {
    'range': [0, 50],
    'title': {'text': 'y', 'font': {'color': 'white'}},
    'linecolor': 'black', 
    'tickcolor': 'black',  
    'dtick': 10, 
    'showgrid': False  
}

fig_dict['layout']['hovermode'] = 'closest'
fig_dict['layout']['font'] = {'color': 'white'} 
fig_dict['layout']['updatemenus'] = [
    {
        "buttons": [
            {
                'args': [None, {'frame': {'duration': 50, 'redraw': False},
                                'fromcurrent': True, 'transition': {'duration': 1000}}],
                'label': 'Play',
                'method': 'animate'
            },
            {
                'args': [[None], {'frame': {'duration': 0, 'redraw': False},
                                  'mode': 'immediate',
                                  'transition': {'duration': 0}}],
                'label': 'Pause',
                'method': 'animate'
            }
        ],
        'direction': 'left',
        'pad': {'r': 10, 't': 87},
        'showactive': False,
        'type': 'buttons',
        'x': 0.1,
        'xanchor': 'right',
        'y': 0,
        'yanchor': 'top'
    }
]


sliders_dict = {
    'active': 0,
    'yanchor': 'top',
    'xanchor': 'left',
    'currentvalue': {
        'font': {'size': 20, 'color': 'black'},
        'prefix': 'Time:',
        'visible': True,
        'xanchor': 'right'
    },
    'transition': {'duration': 300},
    'pad': {'b': 10, 't': 50},
    'len': .9,
    'x': .1,
    'y': 0,
    'steps': []
}

for club in full_play['club'].unique():
    data_dict = {
        'x': full_play.loc[full_play['club'] == club, 'x'],
        'y': full_play.loc[full_play['club'] == club, 'y'],
        'mode': 'markers',
        'text': full_play.loc[full_play['club'] == club, 'displayName'],
        'name': club
    }
    fig_dict['data'].append(data_dict)

initial_frame = {'data': [], 'name': 'Initial'}
fig_dict['frames'].append(initial_frame)

for frame in full_play['frameId'].unique():
    f = {'data': [], 'name': str(frame)}
    
    for club in full_play['club'].unique():
        frame_data = {
            'x': full_play.loc[full_play['frameId'] == frame, 'x'][full_play['club'] == club],
            'y': full_play.loc[full_play['frameId'] == frame, 'y'][full_play['club'] == club],
            'mode': 'markers',
            'text': full_play.loc[full_play['frameId'] == frame, 'displayName'][full_play['club'] == club],
            'name': club
        }
        f['data'].append(frame_data) 

    fig_dict['frames'].append(f)
    
    slider_step = {
        'args': [
            [frame],
            {'frame': {'duration': 0, 'redraw': False},
             'mode': 'immediate',
             'transition': {'duration': 0}}
        ],
        'label': str(frame),
        'method': 'animate'
    }
    sliders_dict['steps'].append(slider_step) 

fig_dict['layout']['sliders'] = [sliders_dict]

fig = go.Figure(fig_dict)

if len(fig_dict['frames']) > 1:
    fig.update(data=fig_dict['frames'][1]['data']) 

fig.update_layout(paper_bgcolor='#242424', plot_bgcolor='#0a4200')
    
fig.show()
# Out:
# <div>                            <div id="21b860f3-1149-417d-929a-644083a0bbcb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("21b860f3-1149-417d-929a-644083a0bbcb")) {                    Plotly.newPlot(                        "21b860f3-1149-417d-929a-644083a0bbcb",                        [{"mode":"markers","name":"WAS","text":["Bobby McCain","William Jackson","Kendall Fuller","Jonathan Allen","Daron Payne","Montez Sweat","Cole Holcomb","James Smith-Williams","Jamin Davis","Benjamin St-Juste","Darrick Forrest"],"x":[43.45,41.49,41.52,39.08,38.83,38.71,40.69,39.66,41.01,42.84,43.75],"y":[27.43,25.74,35.76,31.18,28.28,33.25,29.8,26.93,31.27,28.52,32.43],"type":"scatter"},{"mode":"markers","name":"DET","text":["Jared Goff","Taylor Decker","Josh Reynolds","Dan Skipper","D.J. Chark","Evan Brown","T.J. Hockenson","D'Andre Swift","Logan Stenberg","Penei Sewell","Amon-Ra St. Brown"],"x":[32.01,34.43,31.82,35.1,30.75,35.63,32.22,30.74,35.05,34.76,33.57],"y":[29.86,32.73,32.59,31.52,37.65,29.88,20.43,31.33,28.38,26.96,23.52],"type":"scatter"},{"mode":"markers","name":"football","text":["football"],"x":[36.8300018310547],"y":[30.0699996948242],"type":"scatter"}],                        {"font":{"color":"white"},"hovermode":"closest","sliders":[{"active":0,"currentvalue":{"font":{"color":"black","size":20},"prefix":"Time:","visible":true,"xanchor":"right"},"len":0.9,"pad":{"b":10,"t":50},"steps":[{"args":[[1],{"frame":{"duration":0,"redraw":false},"mode":"immediate","transition":{"duration":0}}],"label":"1","method":"animate"},{"args":[[2],{"frame":{"duration":0,"redraw":false},"mode":"immediate","transition":{"duration":0}}],"label":"2","method":"animate"},{"args":[[3],{"frame":{"duration":0,"redraw":false},"mode":"immediate","transition":{"duration":0}}],"label":"3","method":"animate"},{"args":[[4],{"frame":{"duration":0,"redraw":false},"mode":"immediate","transition":{"duration":0}}],"label":"4","method":"animate"},{"args":[[5],{"frame":{"duration":0,"redraw":false},"mode":"immediate","transition":{"duration":0}}],"label":"5","method":"animate"},{"args":[[6],{"frame":{"duration":0,"redraw":false},"mode":"immediate","transition":{"duration":0}}],"label":"6","method":"animate"},{"args":[[7],{"frame":{"duration":0,"redraw":false},"mode":"immediate","transition":{"duration":0}}],"label":"7","method":"animate"},{"args":[[8],{"frame":{"duration":0,"redraw":false},"mode":"immediate","transition":{"duration":0}}],"label":"8","method":"animate"},{"args":[[9],{"frame":{"duration":0,"redraw":false},"mode":"immediate","transition":{"duration":0}}],"label":"9","method":"animate"},{"args":[[10],{"frame":{"duration":0,"redraw":false},"mode":"immediate","transition":{"duration":0}}],"label":"10","method":"animate"},{"args":[[11],{"frame":{"duration":0,"redraw":false},"mode":"immediate","transition":{"duration":0}}],"label":"11","method":"animate"},{"args":[[12],{"frame":{"duration":0,"redraw":false},"mode":"immediate","transition":{"duration":0}}],"label":"12","method":"animate"},{"args":[[13],{"frame":{"duration":0,"redraw":false},"mode":"immediate","transition":{"duration":0}}],"label":"13","method":"animate"},{"args":[[14],{"frame":{"duration":0,"redraw":false},"mode":"immediate","transition":{"duration":0}}],"label":"14","method":"animate"},{"args":[[15],{"frame":{"duration":0,"redraw":false},"mode":"immediate","transition":{"duration":0}}],"label":"15","method":"animate"},{"args":[[16],{"frame":{"duration":0,"redraw":false},"mode":"immediate","transition":{"duration":0}}],"label":"16","method":"animate"},{"args":[[17],{"frame":{"duration":0,"redraw":false},"mode":"immediate","transition":{"duration":0}}],"label":"17","method":"animate"},{"args":[[18],{"frame":{"duration":0,"redraw":false},"mode":"immediate","tr ...
